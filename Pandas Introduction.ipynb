# %%
import pandas as pd

# %%
import numpy as np

# %%
################# Python Pandas Creating Series #################

# %%
# Creating empty series
ser = pd.Series()

# %%
print (ser)
# Out:
# Series([], dtype: object)

# %%
# Simple array
data = np.array(['g', 'e', 'e', 'k', 's'])

# %%
ser = pd.Series(data)

# %%
print(ser)
# Out:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %%
################# Python Pandas Creating Dataframes #################

# %%
'''
Pandas DataFrame is a two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns). 
A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns. 
Pandas DataFrame consists of three principal components: the data, rows, and columns.
'''
# Out:
# '\nPandas DataFrame is a two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns). \nA Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns. \nPandas DataFrame consists of three principal components: the data, rows, and columns.\n'

# %%
# Calling DataFrame constructor
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# list of strings
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks']

# %%
# Calling DataFrame constructor on list
df = pd.DataFrame(lst)
df
# Out:
#         0
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %%
################# Creating Dataframes from CSV #################

# %%
# Reading the CSV file
df = pd.read_csv("Team Results BD Wednesday-Fall 23.csv")

# %%
# Printing the first 5 rows
df.head()
# Out:
#   Unnamed: 0  Unnamed: 1  Relive  Elite Circle  Your VR  Fusionx
# 0        NaN         NaN     NaN           NaN      NaN      NaN
# 1     Team 1         NaN     9.5           8.5      7.0      8.5
# 2     Team 2         NaN     8.5           9.5      9.5      8.0
# 3     Team 3         NaN     9.0           9.0     10.0      9.0
# 4     Team 4         NaN     8.5           8.5      9.0     10.0

# %%
# Printing the whole data frame
df
# Out:
#   Unnamed: 0  Unnamed: 1  Relive  Elite Circle  Your VR  Fusionx
# 0        NaN         NaN     NaN           NaN      NaN      NaN
# 1     Team 1         NaN     9.5           8.5      7.0      8.5
# 2     Team 2         NaN     8.5           9.5      9.5      8.0
# 3     Team 3         NaN     9.0           9.0     10.0      9.0
# 4     Team 4         NaN     8.5           8.5      9.0     10.0
# 5        NaN         NaN    35.5          35.5     35.5     35.5

# %%
################# Import public datasets to dataframes #################

# %%
# Downloaded spotify dataset from Kaggle
# link: https://www.kaggle.com/datasets/joebeachcapital/30000-spotify-songs/

# %%
# Import the dataset to a dataframe
df = pd.read_csv("spotify/spotify_songs.csv")

# %%
# Printing the first 5 rows
df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
# Applying a filter and displaying the first 5 rows
filters = ["track_artist", "track_name", "track_album_name", "track_album_release_date"]
df.filter(filters).head()
# Out:
#        track_artist                                         track_name  \
# 0        Ed Sheeran  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1          Maroon 5                    Memories - Dillon Francis Remix
# 2      Zara Larsson                    All the Time - Don Diablo Remix
# 3  The Chainsmokers                  Call You Mine - Keanu Silva Remix
# 4     Lewis Capaldi            Someone You Loved - Future Humans Remix
#
#                                     track_album_name track_album_release_date
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05

# %%
# Sorting Dataframes
# Ssorting data frame by track_artist

# format : data.sort_values("track_artist", axis = 0, ascending = True, inplace = True, na_position ='last')
df.sort_values("track_popularity", axis = 0, ascending = False).head()
# Out:
#                      track_id    track_name    track_artist  track_popularity  \
# 20091  2XU0oxnq2qxCpomAAuJY8K  Dance Monkey     Tones and I               100
# 1551   2XU0oxnq2qxCpomAAuJY8K  Dance Monkey     Tones and I               100
# 30202  696DnlkuDOXcMAnKlTgXXK       ROXANNE  Arizona Zervas                99
# 23104  696DnlkuDOXcMAnKlTgXXK       ROXANNE  Arizona Zervas                99
# 21468  696DnlkuDOXcMAnKlTgXXK       ROXANNE  Arizona Zervas                99
#
#                track_album_id                             track_album_name  \
# 20091  0UywfDKYlyiu1b38DRrzYD  Dance Monkey (Stripped Back) / Dance Monkey
# 1551   0UywfDKYlyiu1b38DRrzYD  Dance Monkey (Stripped Back) / Dance Monkey
# 30202  6HJDrXs0hpebaRFKA1sF90                                      ROXANNE
# 23104  6HJDrXs0hpebaRFKA1sF90                                      ROXANNE
# 21468  6HJDrXs0hpebaRFKA1sF90                                      ROXANNE
#
#       track_album_release_date  \
# ...

# %%
# sorting + filtering the same above data
filters = ["track_artist", "track_name", "track_popularity"]
sorted_df = df.sort_values("track_popularity", axis = 0, ascending = False).head()
sorted_df.filter(filters)  # Since the values are limited to 5 by the previous line, we do not need to add .head() method again
# Out:
#          track_artist    track_name  track_popularity
# 20091     Tones and I  Dance Monkey               100
# 1551      Tones and I  Dance Monkey               100
# 30202  Arizona Zervas       ROXANNE                99
# 23104  Arizona Zervas       ROXANNE                99
# 21468  Arizona Zervas       ROXANNE                99
